# %%
import GEOparse

# %%
gse = GEOparse.get_GEO("GSE68951", destdir=".")
print(gse)
# Out:
# 04-Dec-2025 13:08:35 DEBUG utils - Directory . already exists. Skipping.
# 04-Dec-2025 13:08:35 INFO GEOparse - File already exist: using local version.
# 04-Dec-2025 13:08:35 INFO GEOparse - Parsing ./GSE68951_family.soft.gz:
# 04-Dec-2025 13:08:35 DEBUG GEOparse - DATABASE: GeoMiame
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SERIES: GSE68951
# 04-Dec-2025 13:08:35 DEBUG GEOparse - PLATFORM: GPL16770
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688368
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688369
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688370
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688371
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688372
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688373
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688374
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688375
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688376
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688377
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688378
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688379
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688380
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688381
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688382
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688383
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688384
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688385
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688386
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688387
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688388
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688389
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688390
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688391
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688392
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688393
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688394
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688395
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688396
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688397
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688398
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688399
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688400
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688401
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688402
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688403
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688404
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688405
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688406
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688407
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688408
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688409
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688410
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688411
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688412
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688413
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688414
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688415
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688416
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688417
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688418
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688419
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688420
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688421
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688422
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688423
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688424
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688425
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688426
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688427
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688428
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688429
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688430
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688431
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688432
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688433
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688434
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688435
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688436
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688437
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688438
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688439
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688440
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688441
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688442
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688443
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688444
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688445
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688446
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688447
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688448
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688449
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688450
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688451
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688452
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688453
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688454
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688455
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688456
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688457
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688458
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688459
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688460
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688461
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688462
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688463
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688464
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688465
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688466
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688467
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688468
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688469
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688470
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688471
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688472
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688473
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688474
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688475
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688476
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688477
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688478
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688479
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688480
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688481
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688482
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688483
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688484
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688485
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688486
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688487
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688488
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688489
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688490
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688491
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688492
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688493
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688494
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688495
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688496
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688497
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688498
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688499
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688500
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688501
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688502
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688503
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688504
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688505
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688506
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688507
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688508
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688509
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688510
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688511
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688512
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688513
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688514
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688515
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688516
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688517
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688518
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688519
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688520
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688521
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688522
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688523
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688524
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688525
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688526
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688527
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688528
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688529
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688530
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688531
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688532
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688533
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688534
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688535
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688536
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688537
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688538
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688539
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688540
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688541
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688542
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688543
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688544
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688545
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688546
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688547
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688548
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688549
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688550
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688551
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688552
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688553
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688554
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688555
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688556
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688557
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688558
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688559
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688560
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688561
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688562
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688563
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688564
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688565
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688566
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688567
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688568
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688569
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688570
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688571
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688572
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688573
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688574
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688575
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688576
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688577
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688578
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688579
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688580
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688581
# 04-Dec-2025 13:08:35 DEBUG GEOparse - SAMPLE: GSM1688582
# <SERIES: GSE68951 - 215 SAMPLES, 1 d(s)>

# %%
sample = gse.gsms["GSM1688406"]
sample.table.head()
# Out:
#             ID_REF     VALUE
# 0      hsa-miR-507  1.697300
# 1  hsa-miR-548d-5p  2.528559
# 2     hsa-miR-1976  2.317002
# 3      hsa-miR-429  0.702423
# 4     hsa-miR-1973  1.225079

# %%
import numpy as np
import pandas as pd

# %%
def extract_full_info(gse):

    data = [] 
    for gsm_id, sample in gse.gsms.items():

        meta = sample.metadata["characteristics_ch1"]

        patient_id, timepoint, disease = None, None, None
        
        for item in meta:
            if item.startswith("patient id"):
                patient_id = item.split(":")[1].strip()
            if item.startswith("timepoint"):
                timepoint = int(item.split(":")[1].strip())
            if item.startswith("disease"):
                disease = item.split(":")[1].strip()
        if patient_id is None or timepoint is None:
            continue

        mirnas = sample.table["ID_REF"].values
        expr   = sample.table["VALUE"].values.astype(float)

        data.append({
            "gsm": gsm_id,
            "patient": patient_id,
            "timepoint": timepoint,
            "mirna_names": mirnas,
            "expression": expr
        })

    return pd.DataFrame(data)

# %%
df_all = extract_full_info(gse)
df_all.head()
# Out:
#           gsm patient  timepoint  \
# 0  GSM1688368       A          1
# 1  GSM1688369       A          2
# 2  GSM1688370       A          3
# 3  GSM1688371       A          4
# 4  GSM1688372       A          5
#
#                                          mirna_names  \
# 0  [hsa-miR-507, hsa-miR-548d-5p, hsa-miR-1976, h...
# 1  [hsa-miR-507, hsa-miR-548d-5p, hsa-miR-1976, h...
# 2  [hsa-miR-507, hsa-miR-548d-5p, hsa-miR-1976, h...
# 3  [hsa-miR-507, hsa-miR-548d-5p, hsa-miR-1976, h...
# 4  [hsa-miR-507, hsa-miR-548d-5p, hsa-miR-1976, h...
#
#                                           expression
# 0  [1.854979099, 2.184182338, 2.532296403, 1.5180...
# 1  [1.469763084, 2.320244044, 2.111889095, 1.6172...
# 2  [1.44937518, 2.510284729, 2.083508284, 1.23588...
# 3  [1.777522456, 2.724678628, 3.012721615, 1.3907...
# 4  [1.538218176, 2.030509973, 2.470374907, 1.5635...

# %%
df_all.groupby("patient").size()
# Out:
# patient
# A              8
# B              8
# C              8
# D              8
# E              8
# F              8
# G              8
# H              7
# I              8
# J              8
# K              8
# L              8
# M              8
# N              8
# O              8
# P              8
# Q              8
# R              8
# S              7
# T              8
# U              8
# V              8
# W              8
# X              7
# Y              8
# Z              6
# ZZ_control    12
# dtype: int64

# %%
df_all.groupby("patient")["timepoint"].apply(list)
# Out:
# patient
# A                            [1, 2, 3, 4, 5, 6, 7, 8]
# B                            [1, 2, 3, 4, 5, 6, 7, 8]
# C                            [1, 2, 3, 4, 5, 6, 7, 8]
# D                            [1, 2, 3, 4, 5, 6, 7, 8]
# E                            [1, 2, 3, 4, 5, 6, 7, 8]
# F                            [1, 2, 3, 4, 5, 6, 7, 8]
# G                            [1, 2, 3, 4, 5, 6, 7, 8]
# H                               [1, 2, 3, 4, 5, 6, 7]
# I                            [1, 2, 3, 4, 5, 6, 7, 8]
# J                            [1, 2, 3, 4, 5, 6, 7, 8]
# K                            [1, 2, 3, 4, 5, 6, 7, 8]
# L                            [1, 2, 3, 4, 5, 6, 7, 8]
# M                            [1, 2, 3, 4, 5, 6, 7, 8]
# N                            [1, 2, 3, 4, 5, 6, 7, 8]
# O                            [1, 2, 3, 4, 5, 6, 7, 8]
# P                            [1, 2, 3, 4, 5, 6, 7, 8]
# Q                            [1, 2, 3, 4, 5, 6, 7, 8]
# R                            [1, 2, 3, 4, 5, 6, 7, 8]
# S                               [1, 2, 3, 4, 5, 6, 7]
# T                            [1, 2, 3, 4, 5, 6, 7, 8]
# U                            [1, 2, 3, 4, 5, 6, 7, 8]
# V                            [1, 2, 3, 4, 5, 6, 7, 8]
# W                            [1, 2, 3, 4, 5, 6, 7, 8]
# X                               [1, 2, 3, 4, 5, 6, 7]
# Y                            [1, 2, 3, 4, 5, 6, 7, 8]
# Z                                  [1, 2, 3, 4, 5, 6]
# ZZ_control    [1, 10, 11, 12, 2, 3, 4, 5, 6, 7, 8, 9]
# Name: timepoint, dtype: object

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import train_test_split

scaler_classifier = make_pipeline(StandardScaler(), LogisticRegression(max_iter = 5000))
y = df_all["patient"].values
X = np.vstack(df_all["expression"].values)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.linear_model import LogisticRegression

def evaluate_model_logreg(X, y, classifier=None):

    if classifier is None:
        classifier = LogisticRegression(max_iter=5000)

    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=0.3, random_state=42, stratify=y
    )

    classifier.fit(X_train, y_train)

    y_pred = classifier.predict(X_test)

    print(classification_report(y_test, y_pred, zero_division=0))

    return classifier

# %%
cfg = evaluate_model_logreg(X, y, scaler_classifier)
cfg
# Out:
#               precision    recall  f1-score   support
#
#            A       0.00      0.00      0.00         2
#            B       0.00      0.00      0.00         2
#            C       0.67      1.00      0.80         2
#            D       0.00      0.00      0.00         3
#            E       0.00      0.00      0.00         3
#            F       0.33      0.50      0.40         2
#            G       0.00      0.00      0.00         3
#            H       0.00      0.00      0.00         2
#            I       0.00      0.00      0.00         3
#            J       0.33      0.50      0.40         2
#            K       0.00      0.00      0.00         2
#            L       0.00      0.00      0.00         3
#            M       0.00      0.00      0.00         2
#            N       0.00      0.00      0.00         2
#            O       0.50      0.50      0.50         2
#            P       0.00      0.00      0.00         3
#            Q       0.50      0.50      0.50         2
#            R       0.00      0.00      0.00         2
#            S       0.50      0.50      0.50         2
#            T       0.00      0.00      0.00         3
#            U       0.00      0.00      0.00         2
#            V       0.50      0.33      0.40         3
#            W       0.33      0.67      0.44         3
#            X       1.00      1.00      1.00         2
#            Y       1.00      0.50      0.67         2
#            Z       0.00      0.00      0.00         2
#   ZZ_control       1.00      0.50      0.67         4
#
#     accuracy                           0.23        65
#    macro avg       0.25      0.24      0.23        65
# weighted avg       0.25      0.23      0.23        65
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('logisticregression', LogisticRegression(max_iter=5000))])

# %%
from sklearn.model_selection import GroupKFold, GridSearchCV
from sklearn.metrics import accuracy_score, f1_score, classification_report, matthews_corrcoef, make_scorer
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
def evaluate_model_logreg_groupKFold(X, y, groups):
    gkf = GroupKFold(n_splits=5)
    accuracies = []
    f1s = []
    fold = 1

    clf = make_pipeline(StandardScaler(),LogisticRegression(max_iter=5000))
    

    for train_idx, test_idx in gkf.split(X, y, groups):
        print(f"\n====== Fold {fold} ======")
        X_train, X_test = X[train_idx], X[test_idx]
        y_train, y_test = y[train_idx], y[test_idx]

        clf.fit(X_train, y_train)
        y_pred = clf.predict(X_test)

        acc = accuracy_score(y_test, y_pred)
        f1 = f1_score(y_test, y_pred, average="macro")

        print("Accuracy:", acc)
        print("F1 macro:", f1)
        print(classification_report(y_test, y_pred, zero_division=0))

        accuracies.append(acc)
        f1s.append(f1)
        fold += 1

    print("\n=== FINAL LOGREG ===")
    print("Mean Accuracy:", np.mean(accuracies))
    print("Mean F1 Macro:", np.mean(f1s))

# %%
evaluate_model_logreg_groupKFold(X, y, groups)
# Out:
# ====== Fold 1 ======
# Accuracy: 0.0
# F1 macro: 0.0
#               precision    recall  f1-score   support
#
#            A       0.00      0.00      0.00       0.0
#            B       0.00      0.00      0.00       0.0
#            C       0.00      0.00      0.00       0.0
#            E       0.00      0.00      0.00       0.0
#            H       0.00      0.00      0.00       7.0
#            J       0.00      0.00      0.00       8.0
#            L       0.00      0.00      0.00       0.0
#            M       0.00      0.00      0.00       0.0
#            N       0.00      0.00      0.00       0.0
#            P       0.00      0.00      0.00       8.0
#            Q       0.00      0.00      0.00       0.0
#            R       0.00      0.00      0.00       0.0
#            S       0.00      0.00      0.00       0.0
#            V       0.00      0.00      0.00       8.0
#            W       0.00      0.00      0.00       0.0
#            Y       0.00      0.00      0.00       0.0
#            Z       0.00      0.00      0.00       0.0
#   ZZ_control       0.00      0.00      0.00      12.0
#
#     accuracy                           0.00      43.0
#    macro avg       0.00      0.00      0.00      43.0
# weighted avg       0.00      0.00      0.00      43.0
#
#
# ====== Fold 2 ======
# Accuracy: 0.0
# F1 macro: 0.0
#               precision    recall  f1-score   support
#
#            A       0.00      0.00      0.00       0.0
#            B       0.00      0.00      0.00       0.0
#            C       0.00      0.00      0.00       0.0
#            D       0.00      0.00      0.00       0.0
#            E       0.00      0.00      0.00       8.0
#            F       0.00      0.00      0.00       0.0
#            H       0.00      0.00      0.00       0.0
#            I       0.00      0.00      0.00       0.0
#            J       0.00      0.00      0.00       0.0
#            K       0.00      0.00      0.00       8.0
#            L       0.00      0.00      0.00       0.0
#            M       0.00      0.00      0.00       8.0
#            N       0.00      0.00      0.00       0.0
#            P       0.00      0.00      0.00       0.0
#            Q       0.00      0.00      0.00       8.0
#            R       0.00      0.00      0.00       0.0
#            U       0.00      0.00      0.00       0.0
#            V       0.00      0.00      0.00       0.0
#            W       0.00      0.00      0.00       8.0
#            Z       0.00      0.00      0.00       6.0
#   ZZ_control       0.00      0.00      0.00       0.0
#
#     accuracy                           0.00      46.0
#    macro avg       0.00      0.00      0.00      46.0
# weighted avg       0.00      0.00      0.00      46.0
#
#
# ====== Fold 3 ======
# Accuracy: 0.0
# F1 macro: 0.0
#               precision    recall  f1-score   support
#
#            A       0.00      0.00      0.00       0.0
#            B       0.00      0.00      0.00       8.0
#            D       0.00      0.00      0.00       0.0
#            F       0.00      0.00      0.00       8.0
#            H       0.00      0.00      0.00       0.0
#            I       0.00      0.00      0.00       0.0
#            J       0.00      0.00      0.00       0.0
#            L       0.00      0.00      0.00       8.0
#            M       0.00      0.00      0.00       0.0
#            P       0.00      0.00      0.00       0.0
#            Q       0.00      0.00      0.00       0.0
#            R       0.00      0.00      0.00       8.0
#            U       0.00      0.00      0.00       0.0
#            V       0.00      0.00      0.00       0.0
#            Y       0.00      0.00      0.00       8.0
#            Z       0.00      0.00      0.00       0.0
#
#     accuracy                           0.00      40.0
#    macro avg       0.00      0.00      0.00      40.0
# weighted avg       0.00      0.00      0.00      40.0
#
#
# ====== Fold 4 ======
# Accuracy: 0.0
# F1 macro: 0.0
#               precision    recall  f1-score   support
#
#            A       0.00      0.00      0.00       8.0
#            B       0.00      0.00      0.00       0.0
#            C       0.00      0.00      0.00       8.0
#            D       0.00      0.00      0.00       0.0
#            E       0.00      0.00      0.00       0.0
#            G       0.00      0.00      0.00       8.0
#            H       0.00      0.00      0.00       0.0
#            I       0.00      0.00      0.00       0.0
#            J       0.00      0.00      0.00       0.0
#            L       0.00      0.00      0.00       0.0
#            N       0.00      0.00      0.00       8.0
#            O       0.00      0.00      0.00       0.0
#            P       0.00      0.00      0.00       0.0
#            Q       0.00      0.00      0.00       0.0
#            R       0.00      0.00      0.00       0.0
#            S       0.00      0.00      0.00       0.0
#            T       0.00      0.00      0.00       8.0
#            W       0.00      0.00      0.00       0.0
#            Z       0.00      0.00      0.00       0.0
#
#     accuracy                           0.00      40.0
#    macro avg       0.00      0.00      0.00      40.0
# weighted avg       0.00      0.00      0.00      40.0
#
#
# ====== Fold 5 ======
# Accuracy: 0.0
# F1 macro: 0.0
#               precision    recall  f1-score   support
#
#            A       0.00      0.00      0.00       0.0
#            C       0.00      0.00      0.00       0.0
#            D       0.00      0.00      0.00       8.0
#            F       0.00      0.00      0.00       0.0
#            G       0.00      0.00      0.00       0.0
#            I       0.00      0.00      0.00       8.0
#            K       0.00      0.00      0.00       0.0
#            L       0.00      0.00      0.00       0.0
#            M       0.00      0.00      0.00       0.0
#            N       0.00      0.00      0.00       0.0
#            O       0.00      0.00      0.00       8.0
#            R       0.00      0.00      0.00       0.0
#            S       0.00      0.00      0.00       7.0
#            T       0.00      0.00      0.00       0.0
#            U       0.00      0.00      0.00       8.0
#            X       0.00      0.00      0.00       7.0
#
#     accuracy                           0.00      46.0
#    macro avg       0.00      0.00      0.00      46.0
# weighted avg       0.00      0.00      0.00      46.0
#
#
# === FINAL LOGREG ===
# Mean Accuracy: 0.0
# Mean F1 Macro: 0.0

# %%
def build_svm_pca_pipeline():
    return Pipeline([
        ("scaler", StandardScaler()),
        ("pca", PCA()),
        ("svm", SVC(kernel="rbf"))
    ])

# %%
def tune_hyperparameters(pipeline, X, y, groups):
    param_grid = {
        "pca__n_components": [5, 10, 15, 20],
        "svm__C": [0.1, 1, 10],
        "svm__gamma": ["scale", 0.01, 0.001]
    }

    mcc_scorer = make_scorer(matthews_corrcoef)
    gkf = GroupKFold(n_splits=5)

    grid = GridSearchCV(
        estimator=pipeline,
        param_grid=param_grid,
        scoring=mcc_scorer,
        cv=gkf.split(X, y, groups),
        n_jobs=-1,
        verbose=2
    )

    grid.fit(X, y)

    print("Best Params:", grid.best_params_)
    print("Best MCC:", grid.best_score_)

    return grid.best_estimator_

# %%
def evaluate_model(model, X, y, groups):
    gkf = GroupKFold(n_splits=5)
    accuracies = []
    f1s = []
    fold = 1

    for train_idx, test_idx in gkf.split(X, y, groups):
        print(f"\n====== Fold {fold} ======")

        X_train, X_test = X[train_idx], X[test_idx]
        y_train, y_test = y[train_idx], y[test_idx]

        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)

        acc = accuracy_score(y_test, y_pred)
        f1 = f1_score(y_test, y_pred, average="macro")

        print("Accuracy:", acc)
        print("F1:", f1)
        print(classification_report(y_test, y_pred, zero_division=0))

        accuracies.append(acc)
        f1s.append(f1)
        fold += 1

    print("\nFINAL RESULTS")
    print("Mean Accuracy:", np.mean(accuracies))
    print("Mean F1 Macro:", np.mean(f1s))

# %%
def run_svm_pca_experiment(X, y, groups):
    print("Building model")
    pipeline = build_svm_pca_pipeline()

    print("Tuning hyperparameters")
    best_model = tune_hyperparameters(pipeline, X, y, groups)

    print("Evaluating final model")
    evaluate_model(best_model, X, y, groups)

    return best_model

# %%
best_model = run_svm_pca_experiment(X, y, groups)
# Out:
# 🔧 Building model...
# 🔍 Tuning hyperparameters...
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# Best Params: {'pca__n_components': 5, 'svm__C': 0.1, 'svm__gamma': 'scale'}
# Best MCC: 0.0
#
# 📊 Evaluating final model...
#
# ====== Fold 1 ======
# Accuracy: 0.0
# F1: 0.0
#               precision    recall  f1-score   support
#
#            A       0.00      0.00      0.00       0.0
#            B       0.00      0.00      0.00       0.0
#            C       0.00      0.00      0.00       0.0
#            E       0.00      0.00      0.00       0.0
#            H       0.00      0.00      0.00       7.0
#            I       0.00      0.00      0.00       0.0
#            J       0.00      0.00      0.00       8.0
#            K       0.00      0.00      0.00       0.0
#            M       0.00      0.00      0.00       0.0
#            N       0.00      0.00      0.00       0.0
#            O       0.00      0.00      0.00       0.0
#            P       0.00      0.00      0.00       8.0
#            R       0.00      0.00      0.00       0.0
#            T       0.00      0.00      0.00       0.0
#            V       0.00      0.00      0.00       8.0
#            W       0.00      0.00      0.00       0.0
#   ZZ_control       0.00      0.00      0.00      12.0
#
#     accuracy                           0.00      43.0
#    macro avg       0.00      0.00      0.00      43.0
# weighted avg       0.00      0.00      0.00      43.0
#
#
# ====== Fold 2 ======
# Accuracy: 0.0
# F1: 0.0
#               precision    recall  f1-score   support
#
#            E       0.00      0.00      0.00       8.0
#            K       0.00      0.00      0.00       8.0
#            M       0.00      0.00      0.00       8.0
#            Q       0.00      0.00      0.00       8.0
#            W       0.00      0.00      0.00       8.0
#            Z       0.00      0.00      0.00       6.0
#   ZZ_control       0.00      0.00      0.00       0.0
#
#     accuracy                           0.00      46.0
#    macro avg       0.00      0.00      0.00      46.0
# weighted avg       0.00      0.00      0.00      46.0
#
#
# ====== Fold 3 ======
# Accuracy: 0.0
# F1: 0.0
#               precision    recall  f1-score   support
#
#            B       0.00      0.00      0.00       8.0
#            F       0.00      0.00      0.00       8.0
#            L       0.00      0.00      0.00       8.0
#            R       0.00      0.00      0.00       8.0
#            Y       0.00      0.00      0.00       8.0
#   ZZ_control       0.00      0.00      0.00       0.0
#
#     accuracy                           0.00      40.0
#    macro avg       0.00      0.00      0.00      40.0
# weighted avg       0.00      0.00      0.00      40.0
#
#
# ====== Fold 4 ======
# Accuracy: 0.0
# F1: 0.0
#               precision    recall  f1-score   support
#
#            A       0.00      0.00      0.00       8.0
#            C       0.00      0.00      0.00       8.0
#            G       0.00      0.00      0.00       8.0
#            N       0.00      0.00      0.00       8.0
#            T       0.00      0.00      0.00       8.0
#   ZZ_control       0.00      0.00      0.00       0.0
#
#     accuracy                           0.00      40.0
#    macro avg       0.00      0.00      0.00      40.0
# weighted avg       0.00      0.00      0.00      40.0
#
#
# ====== Fold 5 ======
# Accuracy: 0.0
# F1: 0.0
#               precision    recall  f1-score   support
#
#            D       0.00      0.00      0.00       8.0
#            I       0.00      0.00      0.00       8.0
#            O       0.00      0.00      0.00       8.0
#            S       0.00      0.00      0.00       7.0
#            U       0.00      0.00      0.00       8.0
#            X       0.00      0.00      0.00       7.0
#   ZZ_control       0.00      0.00      0.00       0.0
#
#     accuracy                           0.00      46.0
#    macro avg       0.00      0.00      0.00      46.0
# weighted avg       0.00      0.00      0.00      46.0
#
#
# === FINAL RESULTS ===
# Mean Accuracy: 0.0
# Mean F1 Macro: 0.0
# [CV] END ..pca__n_components=5, svm__C=0.1, svm__gamma=scale; total time=   0.1s
# [CV] END ....pca__n_components=5, svm__C=1, svm__gamma=scale; total time=   0.0s
# [CV] END .....pca__n_components=5, svm__C=1, svm__gamma=0.01; total time=   0.0s
# [CV] END ...pca__n_components=5, svm__C=10, svm__gamma=scale; total time=   0.0s
# [CV] END ...pca__n_components=5, svm__C=10, svm__gamma=0.001; total time=   0.0s
# [CV] END .pca__n_components=10, svm__C=0.1, svm__gamma=0.001; total time=   0.0s
# [CV] END .pca__n_components=10, svm__C=0.1, svm__gamma=0.001; total time=   0.0s
# [CV] END ...pca__n_components=10, svm__C=1, svm__gamma=0.001; total time=   0.0s
# [CV] END ...pca__n_components=10, svm__C=1, svm__gamma=0.001; total time=   0.0s
# [CV] END ..pca__n_components=10, svm__C=10, svm__gamma=0.001; total time=   0.0s
# [CV] END ..pca__n_components=10, svm__C=10, svm__gamma=0.001; total time=   0.0s
# [CV] END .pca__n_components=15, svm__C=0.1, svm__gamma=scale; total time=   0.0s
# [CV] END .pca__n_components=15, svm__C=0.1, svm__gamma=scale; total time=   0.0s
# [CV] END ..pca__n_components=15, svm__C=10, svm__gamma=scale; total time=   0.0s
# [CV] END ..pca__n_components=15, svm__C=10, svm__gamma=scale; total time=   0.0s
# [CV] END ..pca__n_components=15, svm__C=10, svm__gamma=scale; total time=   0.0s
# [CV] END ..pca__n_components=15, svm__C=10, svm__gamma=scale; total time=   0.0s
# [CV] END .pca__n_components=20, svm__C=0.1, svm__gamma=0.001; total time=   0.0s
# [CV] END ...pca__n_components=20, svm__C=1, svm__gamma=scale; total time=   0.0s
# [CV] END ....pca__n_components=20, svm__C=1, svm__gamma=0.01; total time=   0.0s
# [CV] END ..pca__n_components=20, svm__C=10, svm__gamma=scale; total time=   0.0s
# [CV] END ..pca__n_components=20, svm__C=10, svm__gamma=0.001; total time=   0.0s
# [CV] END ..pca__n_components=5, svm__C=0.1, svm__gamma=scale; total time=   0.1s
# [CV] END ..pca__n_components=5, svm__C=0.1, svm__gamma=0.001; total time=   0.0s
# [CV] END ....pca__n_components=5, svm__C=1, svm__gamma=scale; total time=   0.0s
# [CV] END ....pca__n_components=5, svm__C=1, svm__gamma=scale; total time=   0.0s
# [CV] END ....pca__n_components=5, svm__C=10, svm__gamma=0.01; total time=   0.0s
# [CV] END ....pca__n_components=5, svm__C=10, svm__gamma=0.01; total time=   0.0s
# [CV] END .pca__n_components=10, svm__C=0.1, svm__gamma=0.001; total time=   0.0s
# [CV] END .pca__n_components=10, svm__C=0.1, svm__gamma=0.001; total time=   0.0s
# [CV] END .pca__n_components=10, svm__C=0.1, svm__gamma=0.001; total time=   0.0s
# [CV] END .pca__n_components=10, svm__C=0.1, svm__gamma=0.001; total time=   0.0s
# [CV] END .pca__n_components=15, svm__C=0.1, svm__gamma=scale; total time=   0.0s
# [CV] END .pca__n_components=15, svm__C=0.1, svm__gamma=scale; total time=   0.0s
# [CV] END .pca__n_components=15, svm__C=0.1, svm__gamma=scale; total time=   0.0s
# [CV] END ..pca__n_components=15, svm__C=0.1, svm__gamma=0.01; total time=   0.0s
# [CV] END ...pca__n_components=20, svm__C=1, svm__gamma=scale; total time=   0.0s
# [CV] END ...pca__n_components=20, svm__C=1, svm__gamma=scale; total time=   0.0s
# [CV] END ...pca__n_components=20, svm__C=1, svm__gamma=scale; total time=   0.0s
# [CV] END ....pca__n_components=20, svm__C=1, svm__gamma=0.01; total time=   0.0s
# [CV] END ....pca__n_components=20, svm__C=1, svm__gamma=0.01; total time=   0.0s
# [CV] END ....pca__n_components=20, svm__C=1, svm__gamma=0.01; total time=   0.0s
# [CV] END ....pca__n_components=20, svm__C=1, svm__gamma=0.01; total time=   0.0s
# [CV] END ....pca__n_components=20, svm__C=1, svm__gamma=0.01; total time=   0.0s
# [CV] END ...pca__n_components=5, svm__C=0.1, svm__gamma=0.01; total time=   0.1s
# [CV] END ...pca__n_components=5, svm__C=0.1, svm__gamma=0.01; total time=   0.0s
# [CV] END ....pca__n_components=5, svm__C=1, svm__gamma=scale; total time=   0.0s
# [CV] END ....pca__n_components=5, svm__C=1, svm__gamma=0.001; total time=   0.0s
# [CV] END ...pca__n_components=5, svm__C=10, svm__gamma=scale; total time=   0.0s
# [CV] END .pca__n_components=10, svm__C=0.1, svm__gamma=scale; total time=   0.0s
# [CV] END ...pca__n_components=10, svm__C=1, svm__gamma=scale; total time=   0.0s
# [CV] END ...pca__n_components=10, svm__C=1, svm__gamma=scale; total time=   0.0s
# [CV] END ..pca__n_components=10, svm__C=10, svm__gamma=scale; total time=   0.0s
# [CV] END ..pca__n_components=10, svm__C=10, svm__gamma=scale; total time=   0.0s
# [CV] END ..pca__n_components=15, svm__C=0.1, svm__gamma=0.01; total time=   0.0s
# [CV] END ..pca__n_components=15, svm__C=0.1, svm__gamma=0.01; total time=   0.0s
# [CV] END ..pca__n_components=15, svm__C=0.1, svm__gamma=0.01; total time=   0.0s
# [CV] END ..pca__n_components=15, svm__C=0.1, svm__gamma=0.01; total time=   0.0s
# [CV] END .pca__n_components=20, svm__C=0.1, svm__gamma=scale; total time=   0.0s
# [CV] END .pca__n_components=20, svm__C=0.1, svm__gamma=scale; total time=   0.0s
# [CV] END .pca__n_components=20, svm__C=0.1, svm__gamma=scale; total time=   0.0s
# [CV] END .pca__n_components=20, svm__C=0.1, svm__gamma=scale; total time=   0.0s
# [CV] END ...pca__n_components=20, svm__C=1, svm__gamma=scale; total time=   0.0s
# [CV] END ...pca__n_components=20, svm__C=1, svm__gamma=scale; total time=   0.0s
# [CV] END ...pca__n_components=20, svm__C=1, svm__gamma=0.001; total time=   0.0s
# [CV] END ...pca__n_components=20, svm__C=10, svm__gamma=0.01; total time=   0.0s
# [CV] END ..pca__n_components=5, svm__C=0.1, svm__gamma=scale; total time=   0.1s
# [CV] END ...pca__n_components=5, svm__C=0.1, svm__gamma=0.01; total time=   0.0s
# [CV] END ...pca__n_components=5, svm__C=10, svm__gamma=scale; total time=   0.0s
# [CV] END ...pca__n_components=5, svm__C=10, svm__gamma=scale; total time=   0.0s
# [CV] END ...pca__n_components=5, svm__C=10, svm__gamma=0.001; total time=   0.0s
# [CV] END ...pca__n_components=5, svm__C=10, svm__gamma=0.001; total time=   0.0s
# [CV] END ....pca__n_components=10, svm__C=1, svm__gamma=0.01; total time=   0.0s
# [CV] END ....pca__n_components=10, svm__C=1, svm__gamma=0.01; total time=   0.0s
# [CV] END ...pca__n_components=10, svm__C=1, svm__gamma=0.001; total time=   0.0s
# [CV] END ...pca__n_components=10, svm__C=1, svm__gamma=0.001; total time=   0.0s
# [CV] END .pca__n_components=15, svm__C=0.1, svm__gamma=0.001; total time=   0.0s
# [CV] END .pca__n_components=15, svm__C=0.1, svm__gamma=0.001; total time=   0.0s
# [CV] END .pca__n_components=15, svm__C=0.1, svm__gamma=0.001; total time=   0.0s
# [CV] END .pca__n_components=15, svm__C=0.1, svm__gamma=0.001; total time=   0.0s
# [CV] END .pca__n_components=20, svm__C=0.1, svm__gamma=scale; total time=   0.0s
# [CV] END .pca__n_components=20, svm__C=0.1, svm__gamma=scale; total time=   0.0s
# [CV] END .pca__n_components=20, svm__C=0.1, svm__gamma=scale; total time=   0.0s
# [CV] END .pca__n_components=20, svm__C=0.1, svm__gamma=scale; total time=   0.0s
# [CV] END ..pca__n_components=20, svm__C=0.1, svm__gamma=0.01; total time=   0.0s
# [CV] END ..pca__n_components=20, svm__C=0.1, svm__gamma=0.01; total time=   0.0s
# [CV] END ..pca__n_components=20, svm__C=0.1, svm__gamma=0.01; total time=   0.0s
# [CV] END ..pca__n_components=20, svm__C=0.1, svm__gamma=0.01; total time=   0.0s
# [CV] END ..pca__n_components=20, svm__C=10, svm__gamma=0.001; total time=   0.0s
# [CV] END ..pca__n_components=20, svm__C=10, svm__gamma=0.001; total time=   0.0s
# [CV] END ..pca__n_components=5, svm__C=0.1, svm__gamma=scale; total time=   0.1s
# [CV] END ..pca__n_components=5, svm__C=0.1, svm__gamma=0.001; total time=   0.0s
# [CV] END .....pca__n_components=5, svm__C=1, svm__gamma=0.01; total time=   0.0s
# [CV] END ....pca__n_components=5, svm__C=1, svm__gamma=0.001; total time=   0.0s
# [CV] END ....pca__n_components=5, svm__C=10, svm__gamma=0.01; total time=   0.0s
# [CV] END ...pca__n_components=5, svm__C=10, svm__gamma=0.001; total time=   0.0s
# [CV] END .pca__n_components=10, svm__C=0.1, svm__gamma=0.001; total time=   0.0s
# [CV] END .pca__n_components=10, svm__C=0.1, svm__gamma=0.001; total time=   0.0s
# [CV] END ...pca__n_components=10, svm__C=1, svm__gamma=0.001; total time=   0.0s
# [CV] END ...pca__n_components=10, svm__C=1, svm__gamma=0.001; total time=   0.0s
# [CV] END .pca__n_components=15, svm__C=0.1, svm__gamma=0.001; total time=   0.0s
# [CV] END ...pca__n_components=15, svm__C=1, svm__gamma=scale; total time=   0.0s
# [CV] END ...pca__n_components=15, svm__C=1, svm__gamma=scale; total time=   0.0s
# [CV] END ...pca__n_components=15, svm__C=1, svm__gamma=scale; total time=   0.0s
# [CV] END ..pca__n_components=15, svm__C=10, svm__gamma=0.001; total time=   0.0s
# [CV] END ..pca__n_components=15, svm__C=10, svm__gamma=0.001; total time=   0.0s
# [CV] END ..pca__n_components=15, svm__C=10, svm__gamma=0.001; total time=   0.0s
# [CV] END .pca__n_components=20, svm__C=0.1, svm__gamma=scale; total time=   0.0s
# [CV] END ....pca__n_components=20, svm__C=1, svm__gamma=0.01; total time=   0.0s
# [CV] END ...pca__n_components=20, svm__C=1, svm__gamma=0.001; total time=   0.0s
# [CV] END ...pca__n_components=20, svm__C=10, svm__gamma=0.01; total time=   0.0s
# [CV] END ..pca__n_components=5, svm__C=0.1, svm__gamma=scale; total time=   0.0s
# [CV] END ...pca__n_components=5, svm__C=0.1, svm__gamma=0.01; total time=   0.0s
# [CV] END ....pca__n_components=5, svm__C=1, svm__gamma=scale; total time=   0.0s
# [CV] END ....pca__n_components=5, svm__C=1, svm__gamma=scale; total time=   0.0s
# [CV] END ...pca__n_components=5, svm__C=10, svm__gamma=scale; total time=   0.0s
# [CV] END ...pca__n_components=5, svm__C=10, svm__gamma=scale; total time=   0.0s
# [CV] END .pca__n_components=10, svm__C=0.1, svm__gamma=scale; total time=   0.0s
# [CV] END .pca__n_components=10, svm__C=0.1, svm__gamma=scale; total time=   0.0s
# [CV] END ..pca__n_components=10, svm__C=0.1, svm__gamma=0.01; total time=   0.0s
# [CV] END ..pca__n_components=10, svm__C=0.1, svm__gamma=0.01; total time=   0.0s
# [CV] END ...pca__n_components=10, svm__C=10, svm__gamma=0.01; total time=   0.0s
# [CV] END ...pca__n_components=10, svm__C=10, svm__gamma=0.01; total time=   0.0s
# [CV] END ...pca__n_components=10, svm__C=10, svm__gamma=0.01; total time=   0.0s
# [CV] END ...pca__n_components=10, svm__C=10, svm__gamma=0.01; total time=   0.0s
# [CV] END ....pca__n_components=15, svm__C=1, svm__gamma=0.01; total time=   0.0s
# [CV] END ....pca__n_components=15, svm__C=1, svm__gamma=0.01; total time=   0.0s
# [CV] END ....pca__n_components=15, svm__C=1, svm__gamma=0.01; total time=   0.0s
# [CV] END ...pca__n_components=15, svm__C=1, svm__gamma=0.001; total time=   0.0s
# [CV] END ...pca__n_components=15, svm__C=1, svm__gamma=0.001; total time=   0.0s
# [CV] END ...pca__n_components=15, svm__C=1, svm__gamma=0.001; total time=   0.0s
# [CV] END ...pca__n_components=15, svm__C=1, svm__gamma=0.001; total time=   0.0s
# [CV] END ...pca__n_components=15, svm__C=1, svm__gamma=0.001; total time=   0.0s
# [CV] END ..pca__n_components=20, svm__C=10, svm__gamma=0.001; total time=   0.0s
# [CV] END ...pca__n_components=5, svm__C=0.1, svm__gamma=0.01; total time=   0.1s
# [CV] END ....pca__n_components=5, svm__C=1, svm__gamma=0.001; total time=   0.0s
# [CV] END ...pca__n_components=5, svm__C=10, svm__gamma=scale; total time=   0.0s
# [CV] END ...pca__n_components=5, svm__C=10, svm__gamma=0.001; total time=   0.0s
# [CV] END .pca__n_components=10, svm__C=0.1, svm__gamma=scale; total time=   0.0s
# [CV] END ..pca__n_components=10, svm__C=0.1, svm__gamma=0.01; total time=   0.0s
# [CV] END ..pca__n_components=10, svm__C=0.1, svm__gamma=0.01; total time=   0.0s
# [CV] END ....pca__n_components=10, svm__C=1, svm__gamma=0.01; total time=   0.0s
# [CV] END ....pca__n_components=10, svm__C=1, svm__gamma=0.01; total time=   0.0s
# [CV] END ...pca__n_components=10, svm__C=10, svm__gamma=0.01; total time=   0.0s
# [CV] END ..pca__n_components=10, svm__C=10, svm__gamma=0.001; total time=   0.0s
# [CV] END ..pca__n_components=10, svm__C=10, svm__gamma=0.001; total time=   0.0s
# [CV] END ..pca__n_components=10, svm__C=10, svm__gamma=0.001; total time=   0.0s
# [CV] END ....pca__n_components=15, svm__C=1, svm__gamma=0.01; total time=   0.0s
# [CV] END ....pca__n_components=15, svm__C=1, svm__gamma=0.01; total time=   0.0s
# [CV] END ....pca__n_components=15, svm__C=1, svm__gamma=0.01; total time=   0.0s
# [CV] END ...pca__n_components=15, svm__C=1, svm__gamma=0.001; total time=   0.0s
# [CV] END .pca__n_components=20, svm__C=0.1, svm__gamma=0.001; total time=   0.0s
# [CV] END .pca__n_components=20, svm__C=0.1, svm__gamma=0.001; total time=   0.0s
# [CV] END ...pca__n_components=20, svm__C=1, svm__gamma=scale; total time=   0.0s
# [CV] END ...pca__n_components=20, svm__C=1, svm__gamma=0.001; total time=   0.0s
# [CV] END ..pca__n_components=20, svm__C=10, svm__gamma=scale; total time=   0.0s
# [CV] END ...pca__n_components=20, svm__C=10, svm__gamma=0.01; total time=   0.0s
# [CV] END ...pca__n_components=5, svm__C=0.1, svm__gamma=0.01; total time=   0.0s
# [CV] END ....pca__n_components=5, svm__C=1, svm__gamma=scale; total time=   0.0s
# [CV] END .....pca__n_components=5, svm__C=1, svm__gamma=0.01; total time=   0.0s
# [CV] END .....pca__n_components=5, svm__C=1, svm__gamma=0.01; total time=   0.0s
# [CV] END ...pca__n_components=5, svm__C=10, svm__gamma=0.001; total time=   0.0s
# [CV] END ...pca__n_components=5, svm__C=10, svm__gamma=0.001; total time=   0.0s
# [CV] END ...pca__n_components=10, svm__C=1, svm__gamma=scale; total time=   0.0s
# [CV] END ...pca__n_components=10, svm__C=1, svm__gamma=scale; total time=   0.0s
# [CV] END ...pca__n_components=10, svm__C=1, svm__gamma=scale; total time=   0.0s
# [CV] END ...pca__n_components=10, svm__C=1, svm__gamma=scale; total time=   0.0s
# [CV] END ..pca__n_components=10, svm__C=10, svm__gamma=0.001; total time=   0.0s
# [CV] END ..pca__n_components=10, svm__C=10, svm__gamma=0.001; total time=   0.0s
# [CV] END .pca__n_components=15, svm__C=0.1, svm__gamma=scale; total time=   0.0s
# [CV] END .pca__n_components=15, svm__C=0.1, svm__gamma=scale; total time=   0.0s
# [CV] END ...pca__n_components=15, svm__C=10, svm__gamma=0.01; total time=   0.0s
# [CV] END ...pca__n_components=15, svm__C=10, svm__gamma=0.01; total time=   0.0s
# [CV] END ..pca__n_components=15, svm__C=10, svm__gamma=0.001; total time=   0.0s
# [CV] END ..pca__n_components=15, svm__C=10, svm__gamma=0.001; total time=   0.0s
# [CV] END ..pca__n_components=15, svm__C=10, svm__gamma=0.001; total time=   0.0s
# [CV] END ..pca__n_components=15, svm__C=10, svm__gamma=0.001; total time=   0.0s
# [CV] END ..pca__n_components=15, svm__C=10, svm__gamma=0.001; total time=   0.0s
# [CV] END .pca__n_components=20, svm__C=0.1, svm__gamma=scale; total time=   0.0s
# [CV] END ..pca__n_components=5, svm__C=0.1, svm__gamma=scale; total time=   0.1s
# [CV] END ..pca__n_components=5, svm__C=0.1, svm__gamma=0.001; total time=   0.0s
# [CV] END ....pca__n_components=5, svm__C=1, svm__gamma=scale; total time=   0.0s
# [CV] END ....pca__n_components=5, svm__C=1, svm__gamma=0.001; total time=   0.0s
# [CV] END ...pca__n_components=5, svm__C=10, svm__gamma=scale; total time=   0.0s
# [CV] END ....pca__n_components=5, svm__C=10, svm__gamma=0.01; total time=   0.0s
# [CV] END .pca__n_components=10, svm__C=0.1, svm__gamma=scale; total time=   0.0s
# [CV] END ...pca__n_components=10, svm__C=1, svm__gamma=scale; total time=   0.0s
# [CV] END ...pca__n_components=10, svm__C=1, svm__gamma=scale; total time=   0.0s
# [CV] END ...pca__n_components=10, svm__C=10, svm__gamma=0.01; total time=   0.0s
# [CV] END ...pca__n_components=10, svm__C=10, svm__gamma=0.01; total time=   0.0s
# [CV] END ...pca__n_components=10, svm__C=10, svm__gamma=0.01; total time=   0.0s
# [CV] END ...pca__n_components=10, svm__C=10, svm__gamma=0.01; total time=   0.0s
# [CV] END ...pca__n_components=15, svm__C=1, svm__gamma=0.001; total time=   0.0s
# [CV] END ...pca__n_components=15, svm__C=1, svm__gamma=0.001; total time=   0.0s
# [CV] END ...pca__n_components=15, svm__C=1, svm__gamma=0.001; total time=   0.0s
# [CV] END ...pca__n_components=15, svm__C=1, svm__gamma=0.001; total time=   0.0s
# [CV] END ..pca__n_components=20, svm__C=0.1, svm__gamma=0.01; total time=   0.0s
# [CV] END .pca__n_components=20, svm__C=0.1, svm__gamma=0.001; total time=   0.0s
# [CV] END ....pca__n_components=20, svm__C=1, svm__gamma=0.01; total time=   0.0s
# [CV] END ..pca__n_components=20, svm__C=10, svm__gamma=scale; total time=   0.0s
# [CV] END ..pca__n_components=20, svm__C=10, svm__gamma=0.001; total time=   0.0s
# [CV] END ...pca__n_components=5, svm__C=0.1, svm__gamma=0.01; total time=   0.0s
# [CV] END ..pca__n_components=5, svm__C=0.1, svm__gamma=0.001; total time=   0.0s
# [CV] END ....pca__n_components=5, svm__C=1, svm__gamma=0.001; total time=   0.0s
# [CV] END ....pca__n_components=5, svm__C=1, svm__gamma=0.001; total time=   0.0s
# [CV] END ....pca__n_components=5, svm__C=10, svm__gamma=0.01; total time=   0.0s
# [CV] END ....pca__n_components=5, svm__C=10, svm__gamma=0.01; total time=   0.0s
# [CV] END ...pca__n_components=10, svm__C=1, svm__gamma=scale; total time=   0.0s
# [CV] END ....pca__n_components=10, svm__C=1, svm__gamma=0.01; total time=   0.0s
# [CV] END ....pca__n_components=10, svm__C=1, svm__gamma=0.01; total time=   0.0s
# [CV] END ....pca__n_components=10, svm__C=1, svm__gamma=0.01; total time=   0.0s
# [CV] END ..pca__n_components=15, svm__C=0.1, svm__gamma=0.01; total time=   0.0s
# [CV] END ..pca__n_components=15, svm__C=0.1, svm__gamma=0.01; total time=   0.0s
# [CV] END ..pca__n_components=15, svm__C=0.1, svm__gamma=0.01; total time=   0.0s
# [CV] END ..pca__n_components=15, svm__C=0.1, svm__gamma=0.01; total time=   0.0s
# [CV] END ..pca__n_components=20, svm__C=0.1, svm__gamma=0.01; total time=   0.0s
# [CV] END .pca__n_components=20, svm__C=0.1, svm__gamma=0.001; total time=   0.0s
# [CV] END .pca__n_components=20, svm__C=0.1, svm__gamma=0.001; total time=   0.0s
# [CV] END .pca__n_components=20, svm__C=0.1, svm__gamma=0.001; total time=   0.0s
# [CV] END .pca__n_components=20, svm__C=0.1, svm__gamma=0.001; total time=   0.0s
# [CV] END .pca__n_components=20, svm__C=0.1, svm__gamma=0.001; total time=   0.0s
# [CV] END ...pca__n_components=20, svm__C=1, svm__gamma=scale; total time=   0.0s
# [CV] END ...pca__n_components=20, svm__C=1, svm__gamma=scale; total time=   0.0s
# [CV] END ..pca__n_components=20, svm__C=10, svm__gamma=0.001; total time=   0.0s
# [CV] END ..pca__n_components=5, svm__C=0.1, svm__gamma=scale; total time=   0.1s
# [CV] END ...pca__n_components=5, svm__C=0.1, svm__gamma=0.01; total time=   0.0s
# [CV] END ..pca__n_components=5, svm__C=0.1, svm__gamma=0.001; total time=   0.0s
# [CV] END .....pca__n_components=5, svm__C=1, svm__gamma=0.01; total time=   0.0s
# [CV] END .....pca__n_components=5, svm__C=1, svm__gamma=0.01; total time=   0.0s
# [CV] END ...pca__n_components=5, svm__C=10, svm__gamma=scale; total time=   0.0s
# [CV] END ....pca__n_components=5, svm__C=10, svm__gamma=0.01; total time=   0.0s
# [CV] END ...pca__n_components=5, svm__C=10, svm__gamma=0.001; total time=   0.0s
# [CV] END ..pca__n_components=10, svm__C=0.1, svm__gamma=0.01; total time=   0.0s
# [CV] END ..pca__n_components=10, svm__C=0.1, svm__gamma=0.01; total time=   0.0s
# [CV] END ...pca__n_components=10, svm__C=1, svm__gamma=0.001; total time=   0.0s
# [CV] END ..pca__n_components=10, svm__C=10, svm__gamma=scale; total time=   0.0s
# [CV] END .pca__n_components=15, svm__C=0.1, svm__gamma=0.001; total time=   0.0s
# [CV] END .pca__n_components=15, svm__C=0.1, svm__gamma=0.001; total time=   0.0s
# [CV] END .pca__n_components=15, svm__C=0.1, svm__gamma=0.001; total time=   0.0s
# [CV] END .pca__n_components=15, svm__C=0.1, svm__gamma=0.001; total time=   0.0s
# [CV] END ...pca__n_components=15, svm__C=10, svm__gamma=0.01; total time=   0.0s
# [CV] END ...pca__n_components=15, svm__C=10, svm__gamma=0.01; total time=   0.0s
# [CV] END ..pca__n_components=15, svm__C=10, svm__gamma=0.001; total time=   0.0s
# [CV] END ..pca__n_components=15, svm__C=10, svm__gamma=0.001; total time=   0.0s
# [CV] END ...pca__n_components=20, svm__C=1, svm__gamma=scale; total time=   0.0s
# [CV] END ...pca__n_components=20, svm__C=1, svm__gamma=0.001; total time=   0.0s
# [CV] END ..pca__n_components=20, svm__C=10, svm__gamma=scale; total time=   0.0s
# [CV] END ..pca__n_components=20, svm__C=10, svm__gamma=0.001; total time=   0.0s
# [CV] END ..pca__n_components=5, svm__C=0.1, svm__gamma=scale; total time=   0.0s
# [CV] END ..pca__n_components=5, svm__C=0.1, svm__gamma=0.001; total time=   0.0s
# [CV] END .....pca__n_components=5, svm__C=1, svm__gamma=0.01; total time=   0.0s
# [CV] END ....pca__n_components=5, svm__C=1, svm__gamma=0.001; total time=   0.0s
# [CV] END .pca__n_components=10, svm__C=0.1, svm__gamma=scale; total time=   0.0s
# [CV] END .pca__n_components=10, svm__C=0.1, svm__gamma=scale; total time=   0.0s
# [CV] END ...pca__n_components=10, svm__C=1, svm__gamma=0.001; total time=   0.0s
# [CV] END ...pca__n_components=10, svm__C=1, svm__gamma=0.001; total time=   0.0s
# [CV] END ...pca__n_components=10, svm__C=1, svm__gamma=0.001; total time=   0.0s
# [CV] END ..pca__n_components=10, svm__C=10, svm__gamma=scale; total time=   0.0s
# [CV] END .pca__n_components=15, svm__C=0.1, svm__gamma=0.001; total time=   0.0s
# [CV] END ...pca__n_components=15, svm__C=1, svm__gamma=scale; total time=   0.0s
# [CV] END ...pca__n_components=15, svm__C=1, svm__gamma=scale; total time=   0.0s
# [CV] END ...pca__n_components=15, svm__C=1, svm__gamma=scale; total time=   0.0s
# [CV] END ...pca__n_components=20, svm__C=1, svm__gamma=0.001; total time=   0.0s
# [CV] END ...pca__n_components=20, svm__C=1, svm__gamma=0.001; total time=   0.0s
# [CV] END ...pca__n_components=20, svm__C=1, svm__gamma=0.001; total time=   0.0s
# [CV] END ...pca__n_components=20, svm__C=1, svm__gamma=0.001; total time=   0.0s
# [CV] END ...pca__n_components=20, svm__C=1, svm__gamma=0.001; total time=   0.0s
# [CV] END ..pca__n_components=20, svm__C=10, svm__gamma=scale; total time=   0.0s
# [CV] END ..pca__n_components=20, svm__C=10, svm__gamma=scale; total time=   0.0s
# [CV] END ..pca__n_components=20, svm__C=10, svm__gamma=scale; total time=   0.0s
# [CV] END ...pca__n_components=5, svm__C=0.1, svm__gamma=0.01; total time=   0.1s
# [CV] END ..pca__n_components=5, svm__C=0.1, svm__gamma=0.001; total time=   0.0s
# [CV] END ....pca__n_components=5, svm__C=1, svm__gamma=scale; total time=   0.0s
# [CV] END .....pca__n_components=5, svm__C=1, svm__gamma=0.01; total time=   0.0s
# [CV] END ....pca__n_components=5, svm__C=1, svm__gamma=0.001; total time=   0.0s
# [CV] END ....pca__n_components=5, svm__C=10, svm__gamma=0.01; total time=   0.0s
# [CV] END ..pca__n_components=10, svm__C=0.1, svm__gamma=0.01; total time=   0.0s
# [CV] END .pca__n_components=10, svm__C=0.1, svm__gamma=0.001; total time=   0.0s
# [CV] END ...pca__n_components=10, svm__C=1, svm__gamma=scale; total time=   0.0s
# [CV] END ....pca__n_components=10, svm__C=1, svm__gamma=0.01; total time=   0.0s
# [CV] END ..pca__n_components=10, svm__C=10, svm__gamma=scale; total time=   0.0s
# [CV] END ..pca__n_components=10, svm__C=10, svm__gamma=scale; total time=   0.0s
# [CV] END ...pca__n_components=15, svm__C=1, svm__gamma=scale; total time=   0.0s
# [CV] END ...pca__n_components=15, svm__C=1, svm__gamma=scale; total time=   0.0s
# [CV] END ....pca__n_components=15, svm__C=1, svm__gamma=0.01; total time=   0.0s
# [CV] END ....pca__n_components=15, svm__C=1, svm__gamma=0.01; total time=   0.0s
# [CV] END ..pca__n_components=20, svm__C=0.1, svm__gamma=0.01; total time=   0.0s
# [CV] END ..pca__n_components=20, svm__C=0.1, svm__gamma=0.01; total time=   0.0s
# [CV] END ..pca__n_components=20, svm__C=0.1, svm__gamma=0.01; total time=   0.0s
# [CV] END ..pca__n_components=20, svm__C=0.1, svm__gamma=0.01; total time=   0.0s
# [CV] END ....pca__n_components=20, svm__C=1, svm__gamma=0.01; total time=   0.0s
# [CV] END ...pca__n_components=20, svm__C=1, svm__gamma=0.001; total time=   0.0s
# [CV] END ...pca__n_components=20, svm__C=10, svm__gamma=0.01; total time=   0.0s
# [CV] END ..pca__n_components=20, svm__C=10, svm__gamma=0.001; total time=   0.0s
# [CV] END ...pca__n_components=5, svm__C=0.1, svm__gamma=0.01; total time=   0.0s
# [CV] END ..pca__n_components=5, svm__C=0.1, svm__gamma=0.001; total time=   0.0s
# [CV] END ....pca__n_components=5, svm__C=1, svm__gamma=0.001; total time=   0.0s
# [CV] END ....pca__n_components=5, svm__C=1, svm__gamma=0.001; total time=   0.0s
# [CV] END ...pca__n_components=5, svm__C=10, svm__gamma=scale; total time=   0.0s
# [CV] END ....pca__n_components=5, svm__C=10, svm__gamma=0.01; total time=   0.0s
# [CV] END ..pca__n_components=10, svm__C=0.1, svm__gamma=0.01; total time=   0.0s
# [CV] END ..pca__n_components=10, svm__C=0.1, svm__gamma=0.01; total time=   0.0s
# [CV] END ..pca__n_components=10, svm__C=0.1, svm__gamma=0.01; total time=   0.0s
# [CV] END .pca__n_components=10, svm__C=0.1, svm__gamma=0.001; total time=   0.0s
# [CV] END ...pca__n_components=10, svm__C=10, svm__gamma=0.01; total time=   0.0s
# [CV] END ..pca__n_components=10, svm__C=10, svm__gamma=0.001; total time=   0.0s
# [CV] END ..pca__n_components=10, svm__C=10, svm__gamma=0.001; total time=   0.0s
# [CV] END ..pca__n_components=10, svm__C=10, svm__gamma=0.001; total time=   0.0s
# [CV] END ..pca__n_components=15, svm__C=10, svm__gamma=scale; total time=   0.0s
# [CV] END ..pca__n_components=15, svm__C=10, svm__gamma=scale; total time=   0.0s
# [CV] END ..pca__n_components=15, svm__C=10, svm__gamma=scale; total time=   0.0s
# [CV] END ..pca__n_components=15, svm__C=10, svm__gamma=scale; total time=   0.0s
# [CV] END ..pca__n_components=15, svm__C=10, svm__gamma=scale; total time=   0.0s
# [CV] END ...pca__n_components=15, svm__C=10, svm__gamma=0.01; total time=   0.0s
# [CV] END ...pca__n_components=15, svm__C=10, svm__gamma=0.01; total time=   0.0s
# [CV] END ...pca__n_components=15, svm__C=10, svm__gamma=0.01; total time=   0.0s
# [CV] END ..pca__n_components=5, svm__C=0.1, svm__gamma=scale; total time=   0.1s
# [CV] END ..pca__n_components=5, svm__C=0.1, svm__gamma=0.001; total time=   0.0s
# [CV] END ....pca__n_components=5, svm__C=1, svm__gamma=scale; total time=   0.0s
# [CV] END ....pca__n_components=5, svm__C=10, svm__gamma=0.01; total time=   0.0s
# [CV] END ...pca__n_components=5, svm__C=10, svm__gamma=0.001; total time=   0.0s
# [CV] END .pca__n_components=10, svm__C=0.1, svm__gamma=scale; total time=   0.0s
# [CV] END .pca__n_components=10, svm__C=0.1, svm__gamma=scale; total time=   0.0s
# [CV] END ....pca__n_components=10, svm__C=1, svm__gamma=0.01; total time=   0.0s
# [CV] END ....pca__n_components=10, svm__C=1, svm__gamma=0.01; total time=   0.0s
# [CV] END .pca__n_components=15, svm__C=0.1, svm__gamma=scale; total time=   0.0s
# [CV] END .pca__n_components=15, svm__C=0.1, svm__gamma=scale; total time=   0.0s
# [CV] END .pca__n_components=15, svm__C=0.1, svm__gamma=scale; total time=   0.0s
# [CV] END ..pca__n_components=15, svm__C=0.1, svm__gamma=0.01; total time=   0.0s
# [CV] END ..pca__n_components=15, svm__C=10, svm__gamma=scale; total time=   0.0s
# [CV] END ...pca__n_components=15, svm__C=10, svm__gamma=0.01; total time=   0.0s
# [CV] END ...pca__n_components=15, svm__C=10, svm__gamma=0.01; total time=   0.0s
# [CV] END ...pca__n_components=15, svm__C=10, svm__gamma=0.01; total time=   0.0s
# [CV] END .pca__n_components=20, svm__C=0.1, svm__gamma=0.001; total time=   0.0s
# [CV] END ....pca__n_components=20, svm__C=1, svm__gamma=0.01; total time=   0.0s
# [CV] END ..pca__n_components=20, svm__C=10, svm__gamma=scale; total time=   0.0s
# [CV] END ...pca__n_components=20, svm__C=10, svm__gamma=0.01; total time=   0.0s
# [CV] END ..pca__n_components=20, svm__C=10, svm__gamma=0.001; total time=   0.0s
# [CV] END ..pca__n_components=5, svm__C=0.1, svm__gamma=scale; total time=   0.1s
# [CV] END ..pca__n_components=5, svm__C=0.1, svm__gamma=0.001; total time=   0.0s
# [CV] END .....pca__n_components=5, svm__C=1, svm__gamma=0.01; total time=   0.0s
# [CV] END .....pca__n_components=5, svm__C=1, svm__gamma=0.01; total time=   0.0s
# [CV] END ...pca__n_components=5, svm__C=10, svm__gamma=0.001; total time=   0.0s
# [CV] END .pca__n_components=10, svm__C=0.1, svm__gamma=scale; total time=   0.0s
# [CV] END ..pca__n_components=10, svm__C=10, svm__gamma=scale; total time=   0.0s
# [CV] END ..pca__n_components=10, svm__C=10, svm__gamma=scale; total time=   0.0s
# [CV] END ..pca__n_components=10, svm__C=10, svm__gamma=scale; total time=   0.0s
# [CV] END ..pca__n_components=10, svm__C=10, svm__gamma=scale; total time=   0.0s
# [CV] END ...pca__n_components=15, svm__C=1, svm__gamma=scale; total time=   0.0s
# [CV] END ...pca__n_components=15, svm__C=1, svm__gamma=scale; total time=   0.0s
# [CV] END ....pca__n_components=15, svm__C=1, svm__gamma=0.01; total time=   0.0s
# [CV] END ....pca__n_components=15, svm__C=1, svm__gamma=0.01; total time=   0.0s
# [CV] END ..pca__n_components=20, svm__C=10, svm__gamma=scale; total time=   0.0s
# [CV] END ..pca__n_components=20, svm__C=10, svm__gamma=scale; total time=   0.0s
# [CV] END ...pca__n_components=20, svm__C=10, svm__gamma=0.01; total time=   0.0s
# [CV] END ...pca__n_components=20, svm__C=10, svm__gamma=0.01; total time=   0.0s
# [CV] END ...pca__n_components=20, svm__C=10, svm__gamma=0.01; total time=   0.0s
# [CV] END ...pca__n_components=20, svm__C=10, svm__gamma=0.01; total time=   0.0s
# [CV] END ...pca__n_components=20, svm__C=10, svm__gamma=0.01; total time=   0.0s
# [CV] END ..pca__n_components=20, svm__C=10, svm__gamma=0.001; total time=   0.0s
